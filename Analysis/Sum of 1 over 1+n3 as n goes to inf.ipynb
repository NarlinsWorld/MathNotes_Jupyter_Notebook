# %%
sum=0.
for n in range(1000000):
    sum=sum.n(digits=50)+(1/(1+n^3)).n(digits=50)
    if(n%10000==0):
        print(n,sum.n(digits=50))
# Out:
# 0 1.0000000000000000000000000000000000000000000000000
# 10000 1.6865033373391238609666047955701860022155060434625
# 20000 1.6865033410886863844021677056768287023776102447978
# 30000 1.6865033417830868486189344297223142854723832511342
# 40000 1.6865033420261316983669509152101325434915895157720
# 50000 1.6865033421386278859246058521601887255102327162800
# 60000 1.6865033421997373118712412718487062110858848865175
# 70000 1.6865033422365845273536099126057562343550345018769
# 80000 1.6865033422604998625210017575954215688299560166141
# 90000 1.6865033422768961767701226976642329350639884703588
# 100000 1.6865033422886243859621052321864380905155451992530
# 110000 1.6865033422973019475707113648960097504457814345903
# 120000 1.6865033423039019530930292171378468999968176174331
# 130000 1.6865033423090383147302296704986676573913418336573
# 140000 1.6865033423131138640980652325652131712009811686501
# 150000 1.6865033423164018118900373135859951274177142823125
# ...

# %%
a = 0.686503342249731
