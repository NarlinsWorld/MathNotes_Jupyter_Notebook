# %%
var('x y')
A=vector([3,3])
r_1=1.5
B=vector([6,4]); r_2=abs(B-A)-r_1

G=circle(A,r_1)+circle(B,r_2)
Q=abs(A-vector([x,y]))-r_1
R=abs(B-vector([x,y]))-r_2
eq1=Q==R
G+=implicit_plot(eq1, (0,10), (0,6))
show(G)
# Out:
# Graphics object consisting of 3 graphics primitives
